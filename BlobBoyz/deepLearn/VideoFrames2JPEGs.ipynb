# %% [markdown]
# # Execute video frame extraction in python

# %%
import cv2
import os
from VideoFrameExtraction import *

# %%
myVideo = "./videos/2018 4 10 11 57 23 [360p].mp4";#modify
output = "./outputPath/";

# %%
video2frames(inputPath=myVideo, outPath=output)
# Out:
# Reading frame number 0
# Reading frame number 1
# Reading frame number 2
# Reading frame number 3
# Reading frame number 4
# Reading frame number 5
# Reading frame number 6
# Reading frame number 7
# Reading frame number 8
# Reading frame number 9
# Reading frame number 10
# Reading frame number 11
# Reading frame number 12
# Reading frame number 13
# Reading frame number 14
# Reading frame number 15
# Reading frame number 16
# Reading frame number 17
# Reading frame number 18
# Reading frame number 19
# Reading frame number 20
# Reading frame number 21
# Reading frame number 22
# Reading frame number 23
# Reading frame number 24
# Reading frame number 25
# Reading frame number 26
# Reading frame number 27
# Reading frame number 28
# Reading frame number 29
# Reading frame number 30
# Reading frame number 31
# Reading frame number 32
# Reading frame number 33
# Reading frame number 34
# Reading frame number 35
# Reading frame number 36
# Reading frame number 37
# ...

# %% [markdown]
# # Initialize files for human-expert data labeling

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Frames": range(1,1714+1)})

# %%
df.iloc[0:2]
# Out:
#    Frames
# 0       1
# 1       2

# %%
df.to_csv("./LabelTemplate.csv")
